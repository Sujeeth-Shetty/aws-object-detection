# %% [markdown]
# # Download the Data

# %%
# !pip3 install tqdm
# !pip3 install pillow --upgrade
# Out:
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages (4.46.0)
# Collecting pillow
#   Downloading Pillow-7.2.0-cp36-cp36m-manylinux1_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 3.0 MB/s eta 0:00:01
# Installing collected packages: pillow
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
# Successfully installed pillow-7.2.0

# %%
# %matplotlib inline

import os
import tarfile
import urllib
import shutil
import json
import random
import numpy as np
import boto3
import sagemaker

from tqdm import tqdm
from sagemaker.amazon.amazon_estimator import get_image_uri
from matplotlib import pyplot as plt
from xml.etree import ElementTree as ET
from PIL import Image, ImageDraw, ImageFont

urls = ['http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz',
        'http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz']

def download_and_extract(data_dir, download_dir):
    for url in urls:
        target_file = url.split('/')[-1]
        if target_file not in os.listdir(download_dir):
            print('Downloading', url)
            urllib.request.urlretrieve(url, os.path.join(download_dir, target_file))
            tf = tarfile.open(url.split('/')[-1])
            tf.extractall(data_dir)
        else:
            print('Already downloaded', url)

if not os.path.isdir('data'):
    os.mkdir('data')

download_and_extract('data', '.')
# Out:
# Downloading http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# Downloading http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz

# %% [markdown]
# # Extracting Annotations from XML Format

# %%
xml_dir = 'data/annotations/xmls/'
xml_files = [os.path.join(xml_dir, x) for x in os.listdir(xml_dir) if x[-3:] == 'xml']
xml_files[0]
# Out:
# 'data/annotations/xmls/american_pit_bull_terrier_156.xml'

# %%
classes = ['cat', 'dog']
categories = [
    {
        'class_id': 0,
        'name': 'cat'
    },
    {
        'class_id': 1,
        'name': 'dog'
    }
]

# %%
def extract_annotation(xml_file_path):
    
    tree = ET.parse(xml_file_path)
    root = tree.getroot()
    annotation = {}
    
    annotation['file'] = root.find('filename').text
    annotation['categories'] = categories
    
    size = root.find('size')
    
    annotation['image_size'] = [{
        'width': int(size.find('width').text),
        'height': int(size.find('height').text),
        'depth': int(size.find('depth').text)
    }]
    
    annotation['annotations'] = []
    
    for item in root.iter('object'):
        class_id = classes.index(item.find('name').text)
        ymin, xmin, ymax, xmax = None, None, None, None
        
        for box in item.findall('bndbox'):
            xmin = int(box.find("xmin").text)
            ymin = int(box.find("ymin").text)
            xmax = int(box.find("xmax").text)
            ymax = int(box.find("ymax").text)
        
            if all([xmin, ymin, xmax, ymax]) is not None:
                 annotation['annotations'].append({
                     'class_id': class_id,
                     'left': xmin,
                     'top': ymin,
                     'width': xmax - xmin,
                     'height': ymax - ymin
                 })
    return annotation

# %%
extract_annotation(xml_files[0])
# Out:
# {'file': 'american_pit_bull_terrier_156.jpg',
#  'categories': [{'class_id': 0, 'name': 'cat'},
#   {'class_id': 1, 'name': 'dog'}],
#  'image_size': [{'width': 215, 'height': 216, 'depth': 3}],
#  'annotations': [{'class_id': 1,
#    'left': 62,
#    'top': 27,
#    'width': 131,
#    'height': 113}]}

# %% [markdown]
# # Visualize Data

# %%
def plot_example(plt, annot, image_file_path, rows, cols, index):
    img = Image.open(image_file_path)
    draw = ImageDraw.Draw(img)
    font = ImageFont.truetype('/usr/share/fonts/dejavu/DejaVuSerif-Bold.ttf', 20)
    
    for a in annot['annotations']:
        box = [
            int(a['left']), int(a['top']),
            int(a['left']) + int(a['width']),
            int(a['top']) + int(a['height'])
        ]
        draw.rectangle(box, outline='yellow', width=4)
        draw.text((box[0], box[1]), classes[int(a['class_id'])], font=font)
    plt.subplot(rows, cols, index + 1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img)
    return plt

def show_random_annotations(plt):
    plt.figure(figsize=(16, 16))
    for i in range(0, 9):
        index = random.randint(0, len(xml_files) - 1)
        
        annot = extract_annotation(xml_files[index])
        image_file_path = os.path.join('data/images/', annot['file'])

        plt = plot_example(plt, annot, image_file_path, 3, 3, i)
    plt.show()

# %%
show_random_annotations(plt)

# %% [markdown]
# # SageMaker Setup

# %%
role = sagemaker.get_execution_role()
bucket_name='petsdata-od'

training_image=get_image_uri(boto3.Session().region_name,'object-detection',repo_version='latest')
print(training_image)
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 825641698319.dkr.ecr.us-east-2.amazonaws.com/object-detection:latest

# %%
folders = ['train', 'train_annotation', 'validation', 'validation_annotation']

for folder in folders:
    if os.path.isdir(folder):
        shutil.rmtree(folder)
    os.mkdir(folder)

# %% [markdown]
# # Preparing Data for SageMaker

# %%
print('Total examples:', len(xml_files))
# Out:
# Total examples: 3686

# %%
for xml_file in tqdm(xml_files):
    target_set = 'train' if random.randint(0, 99) < 75 else 'validation'
    annot = extract_annotation(xml_file)
    image_file_path = os.path.join('data/images/', annot['file'])
    image_target_path = os.path.join(target_set, annot['file'])
    shutil.copy(image_file_path, image_target_path)
    json_file_path = os.path.join(target_set + '_annotation', annot['file'][:-3] + 'json')
    with open(json_file_path, 'w') as f:
        json.dump(annot, f)
# Out:
# 100%|██████████| 3686/3686 [00:01<00:00, 2327.13it/s]

# %%
train_images = os.listdir('train')
train_annots = os.listdir('train_annotation')

# %%
print(len(train_annots), len(train_images))
# Out:
# 2747 2747

# %%
for image in train_images:
    key = image.split('.')[0]
    json_file = key + '.json'
    if json_file not in train_annots:
        print('Not found', json_file)

# %% [markdown]
# # Uploading Data to S3

# %%
sess=sagemaker.Session()
print('Uploading data...')

s3_train_path=sess.upload_data(path='train', bucket=bucket_name,key_prefix='train')
print(s3_train_path)
print('Training Images Uploaded')

s3_val_path=sess.upload_data(path='validation', bucket=bucket_name,key_prefix='validation')
print('validation Images Uploaded')

s3_train_ann_path=sess.upload_data(path='train_annotation', bucket=bucket_name,key_prefix='train_annotation')
print('Training Annotations Uploaded')

s3_val_ann_path=sess.upload_data(path='validation_annotation', bucket=bucket_name,key_prefix='validation_annotation')
print('validation annotations Uploaded')
# Out:
# Uploading data...
# s3://petsdata-od/train
# Training Images Uploaded
# validation Images Uploaded
# Training Annotations Uploaded
# validation annotations Uploaded

# %% [markdown]
# # SageMaker Estimator

# %%
model = sagemaker.estimator.Estimator(
    training_image,
    role=role,
    train_instance_type='ml.p3.2xlarge', 
    #train_instance_type= 'ml.m4.xlarge',
    train_instance_count=1,
    train_volume_size=100,
    train_max_run=36000,
    input_mode='File', #for JSON
    output_path= 's3://petsdata-od/output',
    sagemaker_session=sess
)
# Out:
# WARNING:root:Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# # Hyperparameters

# %%
model.set_hyperparameters(
    base_network='resnet-50',
    num_classes=2,
    use_pretrained_model=1,
    mini_batch_size=16,
    epochs=15,
    learning_rate=0.001,
    optimizer='sgd',
    lr_scheduler_step='10',
    lr_scheduler_factor=0.1,
    momentum=0.9,
    weight_decay=0.0005,
    overlap_threshold=0.5,
    nms_threshold=0.45,
    image_shape=512,
    num_training_samples=len(train_annots)
)

# %% [markdown]
# # Data Channels

# %%
from sagemaker.session import s3_input
train_data = sagemaker.session.s3_input(s3_train_path, distribution='FullyReplicated',
                                       content_type='application/x-image',
                                        s3_data_type='S3Prefix')

validation_data = sagemaker.session.s3_input(s3_val_path, distribution='FullyReplicated',
                                       content_type='application/x-image',
                                        s3_data_type='S3Prefix')

train_ann_data = sagemaker.session.s3_input(s3_train_ann_path, distribution='FullyReplicated',
                                       content_type='application/x-image',
                                        s3_data_type='S3Prefix')

validation_ann_data = sagemaker.session.s3_input(s3_val_ann_path, distribution='FullyReplicated',
                                       content_type='application/x-image',
                                        s3_data_type='S3Prefix')
# Out:
# WARNING:sagemaker:'s3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# WARNING:sagemaker:'s3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# WARNING:sagemaker:'s3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# WARNING:sagemaker:'s3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
data_channels= {
    'train': train_data,
    'validation': validation_data,
    'train_annotation': train_ann_data,
    'validation_annotation': validation_ann_data
}

# %%
data_channels
# Out:
# {'train': <sagemaker.inputs.s3_input at 0x7effd1d45630>,
#  'validation': <sagemaker.inputs.s3_input at 0x7effd1d45748>,
#  'train_annotation': <sagemaker.inputs.s3_input at 0x7effd1d45048>,
#  'validation_annotation': <sagemaker.inputs.s3_input at 0x7f000578b978>}

# %% [markdown]
# # Model Training

# %%
model.fit(inputs=data_channels,logs=True)
# Out:
# 2020-07-15 02:41:28 Starting - Starting the training job...
# 2020-07-15 02:41:30 Starting - Launching requested ML instances......
# 2020-07-15 02:42:34 Starting - Preparing the instances for training......
# 2020-07-15 02:43:48 Downloading - Downloading input data......
# 2020-07-15 02:44:50 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# [07/15/2020 02:45:14 INFO 140060376446784] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'label_width': u'350', u'early_stopping_min_epochs': u'10', u'epochs': u'30', u'overlap_threshold': u'0.5', u'lr_scheduler_factor': u'0.1', u'_num_kv_servers': u'auto', u'weight_decay': u'0.0005', u'mini_batch_size': u'32', u'use_pretrained_model': u'0', u'freeze_layer_pattern': u'', u'lr_scheduler_step': u'', u'early_stopping': u'False', u'early_stopping_patience': u'5', u'momentum': u'0.9', u'num_training_samples': u'', u'optimizer': u'sgd', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.0', u'learning_rate': u'0.001', u'kv_store': u'device', u'nms_threshold': u'0.45', u'num_classes': u'', u'base_network': u'vgg-16', u'nms_topk': u'400', u'_kvstore': u'device', u'image_shape': u'300'}
# [07/15/2020 02:45:14 INFO 140060376446784] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'learning_rate': u'0.001', u'epochs': u'15', u'nms_threshold': u'0.45', u'optimizer': u'sgd', u'base_network': u'resnet-50', u'image_shape': u'512', u'lr_scheduler_step': u'10', u'momentum': u'0.9', u'overlap_threshold': u'0.5', u'num_training_samples': u'2747', u'mini_batch_size': u'16', u'weight_decay': u'0.0005', u'use_pretrained_model': u'1', u'num_classes': u'2', u'lr_scheduler_factor': u'0.1'}
# [07/15/2020 02:45:14 INFO 140060376446784] Final configuration: {u'label_width': u'350', u'early_stopping_min_epochs': u'10', u'epochs': u'15', u'overlap_threshold': u'0.5', u'lr_scheduler_factor': u'0.1', u'_num_kv_servers': u'auto', u'weight_decay': u'0.0005', u'mini_batch_size': u'16', u'use_pretrained_model': u'1', u'freeze_layer_pattern': u'', u'lr_scheduler_step': u'10', u'early_stopping': u'False', u'early_stopping_patience': u'5', u'momentum': u'0.9', u'num_training_samples': u'2747', u'optimizer': u'sgd', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.0', u'learning_rate': u'0.001', u'kv_store': u'device', u'nms_threshold': u'0.45', u'num_classes': u'2', u'base_network': u'resnet-50', u'nms_topk': u'400', u'_kvstore': u'device', u'image_shape': u'512'}
# Process 1 is a worker.
# [07/15/2020 02:45:14 INFO 140060376446784] Using default worker.
#
# 2020-07-15 02:45:10 Training - Training image download completed. Training in progress.[07/15/2020 02:45:14 INFO 140060376446784] Loaded iterator creator application/x-image for content type ('application/x-image', '1.0')
# [07/15/2020 02:45:14 INFO 140060376446784] Loaded iterator creator application/x-recordio for content type ('application/x-recordio', '1.0')
# [07/15/2020 02:45:14 INFO 140060376446784] Loaded iterator creator image/png for content type ('image/png', '1.0')
# [07/15/2020 02:45:14 INFO 140060376446784] Loaded iterator creator image/jpeg for content type ('image/jpeg', '1.0')
# [07/15/2020 02:45:14 INFO 140060376446784] Checkpoint loading and saving are disabled.
# [07/15/2020 02:45:15 INFO 140060376446784] nvidia-smi took: 0.0252292156219 secs to identify 1 gpus
# Creating .rec file from /opt/ml/input/data/train/train.lst in /opt/ml/input/data/train
# time: 0.0271799564362  count: 0
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# time: 1.30632591248  count: 1000
# time: 1.04367113113  count: 2000
# Corrupt JPEG data: premature end of data segment
# Creating .rec file from /opt/ml/input/data/validation/val.lst in /opt/ml/input/data/validation
# time: 0.0126700401306  count: 0
# [07/15/2020 02:45:21 INFO 140060376446784] Number of GPUs being used: 1
# [07/15/2020 02:45:21 WARNING 140060376446784] Training images are resized to image shape (3, 512, 512)
# [02:45:21] /opt/brazil-pkg-cache/packages/MXNetECL/MXNetECL-v1.4.1.1911.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/train/train.rec, use 7 threads for decoding..
# [02:45:22] /opt/brazil-pkg-cache/packages/MXNetECL/MXNetECL-v1.4.1.1911.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/train/train.rec, label padding width: 350
# [07/15/2020 02:45:24 WARNING 140060376446784] Validation images are resized to image shape (3, 512, 512)
# [02:45:24] /opt/brazil-pkg-cache/packages/MXNetECL/MXNetECL-v1.4.1.1911.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/validation/val.rec, use 7 threads for decoding..
# [02:45:24] /opt/brazil-pkg-cache/packages/MXNetECL/MXNetECL-v1.4.1.1911.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/validation/val.rec, label padding width: 350
# [07/15/2020 02:45:26 INFO 140060376446784] Number of GPUs being used: 1
# [07/15/2020 02:45:26 INFO 140060376446784] Using [gpu(0)] as training context.
# [07/15/2020 02:45:26 INFO 140060376446784] Number of GPUs being used: 1
# [07/15/2020 02:45:26 INFO 140060376446784] Create Store: device
# [07/15/2020 02:45:26 INFO 140060376446784] Using (gpu(0)) as training context.
# [07/15/2020 02:45:26 INFO 140060376446784] Start training from pretrained model 1.
# [02:45:26] /opt/brazil-pkg-cache/packages/MXNetECL/MXNetECL-v1.4.1.1911.0/AL2012/generic-flavor/src/src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v0.8.0. Attempting to upgrade...
# [02:45:26] /opt/brazil-pkg-cache/packages/MXNetECL/MXNetECL-v1.4.1.1911.0/AL2012/generic-flavor/src/src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
# [07/15/2020 02:45:27 INFO 140060376446784] Loaded pretrained model parameters.
# [07/15/2020 02:45:42 INFO 140060376446784] Creating a new state instance.
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1594781142.071403, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection"}, "StartTime": 1594781142.071299}
#
# [02:45:42] /opt/brazil-pkg-cache/packages/MXNetECL/MXNetECL-v1.4.1.1911.0/AL2012/generic-flavor/src/src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [07/15/2020 02:46:19 INFO 140060376446784] Epoch:    0, batches:    100, num_examples:   1600, 43.0 samples/sec, epoch time so far:  0:00:37.229218
# [07/15/2020 02:46:41 WARNING 140060376446784] Expected number of batches: 171, did not match the number of batches processed: 172. This may happen when some images or annotations are invalid and cannot be parsed. Please check the dataset and ensure it follows the format in the documentation.
# [07/15/2020 02:46:41 INFO 140060376446784] #quality_metric: host=algo-1, epoch=0, batch=172 train cross_entropy <loss>=(1.10366550982996)
# [07/15/2020 02:46:41 INFO 140060376446784] #quality_metric: host=algo-1, epoch=0, batch=172 train smooth_l1 <loss>=(0.6423321896216512)
# [07/15/2020 02:46:41 INFO 140060376446784] Round of batches complete
# [07/15/2020 02:46:41 INFO 140060376446784] Updated the metrics
# [07/15/2020 02:46:53 INFO 140060376446784] #quality_metric: host=algo-1, epoch=0, validation mAP <score>=(0.08606436867619427)
# [07/15/2020 02:46:53 INFO 140060376446784] Updating the best model with validation-mAP=0.08606436867619427
# [07/15/2020 02:46:53 INFO 140060376446784] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/15/2020 02:46:53 INFO 140060376446784] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1594781213.268815, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 0}, "StartTime": 1594781142.071735}
#
# [07/15/2020 02:47:25 INFO 140060376446784] Epoch:    1, batches:    100, num_examples:   1600, 49.5 samples/sec, epoch time so far:  0:00:32.324243
# [07/15/2020 02:47:47 WARNING 140060376446784] Expected number of batches: 171, did not match the number of batches processed: 172. This may happen when some images or annotations are invalid and cannot be parsed. Please check the dataset and ensure it follows the format in the documentation.
# [07/15/2020 02:47:47 INFO 140060376446784] #quality_metric: host=algo-1, epoch=1, batch=172 train cross_entropy <loss>=(0.8657275318099178)
# [07/15/2020 02:47:47 INFO 140060376446784] #quality_metric: host=algo-1, epoch=1, batch=172 train smooth_l1 <loss>=(0.5875593740389179)
# [07/15/2020 02:47:47 INFO 140060376446784] Round of batches complete
# [07/15/2020 02:47:47 INFO 140060376446784] Updated the metrics
# [07/15/2020 02:47:58 INFO 140060376446784] #quality_metric: host=algo-1, epoch=1, validation mAP <score>=(0.302552067397606)
# [07/15/2020 02:47:58 INFO 140060376446784] Updating the best model with validation-mAP=0.302552067397606
# [07/15/2020 02:47:58 INFO 140060376446784] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/15/2020 02:47:58 INFO 140060376446784] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1594781278.181164, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 1}, "StartTime": 1594781213.268996}
#
# [07/15/2020 02:48:30 INFO 140060376446784] Epoch:    2, batches:    100, num_examples:   1600, 49.6 samples/sec, epoch time so far:  0:00:32.247576
# [07/15/2020 02:48:52 WARNING 140060376446784] Expected number of batches: 171, did not match the number of batches processed: 172. This may happen when some images or annotations are invalid and cannot be parsed. Please check the dataset and ensure it follows the format in the documentation.
# [07/15/2020 02:48:52 INFO 140060376446784] #quality_metric: host=algo-1, epoch=2, batch=172 train cross_entropy <loss>=(0.7327112628666731)
# [07/15/2020 02:48:52 INFO 140060376446784] #quality_metric: host=algo-1, epoch=2, batch=172 train smooth_l1 <loss>=(0.539121918394515)
# [07/15/2020 02:48:52 INFO 140060376446784] Round of batches complete
# [07/15/2020 02:48:52 INFO 140060376446784] Updated the metrics
# [07/15/2020 02:49:03 INFO 140060376446784] #quality_metric: host=algo-1, epoch=2, validation mAP <score>=(0.6324618641165286)
# [07/15/2020 02:49:03 INFO 140060376446784] Updating the best model with validation-mAP=0.6324618641165286
# [07/15/2020 02:49:03 INFO 140060376446784] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/15/2020 02:49:03 INFO 140060376446784] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1594781343.14926, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 2}, "StartTime": 1594781278.181387}
#
# [07/15/2020 02:49:35 INFO 140060376446784] Epoch:    3, batches:    100, num_examples:   1600, 49.5 samples/sec, epoch time so far:  0:00:32.318767
# [07/15/2020 02:49:57 INFO 140060376446784] #quality_metric: host=algo-1, epoch=3, batch=171 train cross_entropy <loss>=(0.649229928670715)
# [07/15/2020 02:49:57 INFO 140060376446784] #quality_metric: host=algo-1, epoch=3, batch=171 train smooth_l1 <loss>=(0.4586667763623546)
# [07/15/2020 02:49:57 INFO 140060376446784] Round of batches complete
# [07/15/2020 02:49:57 INFO 140060376446784] Updated the metrics
# [07/15/2020 02:50:08 INFO 140060376446784] #quality_metric: host=algo-1, epoch=3, validation mAP <score>=(0.8167533565374694)
# [07/15/2020 02:50:08 INFO 140060376446784] Updating the best model with validation-mAP=0.8167533565374694
# [07/15/2020 02:50:08 INFO 140060376446784] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/15/2020 02:50:08 INFO 140060376446784] #progress_metric: host=algo-1, completed 26 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1594781408.260046, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 3}, "StartTime": 1594781343.149462}
#
# [07/15/2020 02:50:40 INFO 140060376446784] Epoch:    4, batches:    100, num_examples:   1600, 49.1 samples/sec, epoch time so far:  0:00:32.556320
# [07/15/2020 02:51:02 WARNING 140060376446784] Expected number of batches: 171, did not match the number of batches processed: 172. This may happen when some images or annotations are invalid and cannot be parsed. Please check the dataset and ensure it follows the format in the documentation.
# [07/15/2020 02:51:02 INFO 140060376446784] #quality_metric: host=algo-1, epoch=4, batch=172 train cross_entropy <loss>=(0.5973678164796781)
# [07/15/2020 02:51:02 INFO 140060376446784] #quality_metric: host=algo-1, epoch=4, batch=172 train smooth_l1 <loss>=(0.37871366287851094)
# [07/15/2020 02:51:02 INFO 140060376446784] Round of batches complete
# [07/15/2020 02:51:02 INFO 140060376446784] Updated the metrics
# [07/15/2020 02:51:14 INFO 140060376446784] #quality_metric: host=algo-1, epoch=4, validation mAP <score>=(0.8996191381706569)
# [07/15/2020 02:51:14 INFO 140060376446784] Updating the best model with validation-mAP=0.8996191381706569
# [07/15/2020 02:51:14 INFO 140060376446784] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/15/2020 02:51:14 INFO 140060376446784] #progress_metric: host=algo-1, completed 33 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1594781474.489176, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 4}, "StartTime": 1594781408.260298}
#
# [07/15/2020 02:51:46 INFO 140060376446784] Epoch:    5, batches:    100, num_examples:   1600, 49.5 samples/sec, epoch time so far:  0:00:32.321899
# [07/15/2020 02:52:08 WARNING 140060376446784] Expected number of batches: 171, did not match the number of batches processed: 172. This may happen when some images or annotations are invalid and cannot be parsed. Please check the dataset and ensure it follows the format in the documentation.
# [07/15/2020 02:52:08 INFO 140060376446784] #quality_metric: host=algo-1, epoch=5, batch=172 train cross_entropy <loss>=(0.561677487822544)
# [07/15/2020 02:52:08 INFO 140060376446784] #quality_metric: host=algo-1, epoch=5, batch=172 train smooth_l1 <loss>=(0.3288441087679257)
# [07/15/2020 02:52:08 INFO 140060376446784] Round of batches complete
# [07/15/2020 02:52:08 INFO 140060376446784] Updated the metrics
# [07/15/2020 02:52:21 INFO 140060376446784] #quality_metric: host=algo-1, epoch=5, validation mAP <score>=(0.9544956780349256)
# [07/15/2020 02:52:21 INFO 140060376446784] Updating the best model with validation-mAP=0.9544956780349256
# [07/15/2020 02:52:21 INFO 140060376446784] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/15/2020 02:52:21 INFO 140060376446784] #progress_metric: host=algo-1, completed 40 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 6, "sum": 6.0, "min": 6}}, "EndTime": 1594781541.613653, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 5}, "StartTime": 1594781474.489366}
#
# [07/15/2020 02:52:53 INFO 140060376446784] Epoch:    6, batches:    100, num_examples:   1600, 49.5 samples/sec, epoch time so far:  0:00:32.350187
# [07/15/2020 02:53:15 INFO 140060376446784] #quality_metric: host=algo-1, epoch=6, batch=171 train cross_entropy <loss>=(0.5403366011790918)
# [07/15/2020 02:53:15 INFO 140060376446784] #quality_metric: host=algo-1, epoch=6, batch=171 train smooth_l1 <loss>=(0.29672752910655825)
# [07/15/2020 02:53:15 INFO 140060376446784] Round of batches complete
# [07/15/2020 02:53:15 INFO 140060376446784] Updated the metrics
# [07/15/2020 02:53:27 INFO 140060376446784] #quality_metric: host=algo-1, epoch=6, validation mAP <score>=(0.9711081911611339)
# [07/15/2020 02:53:27 INFO 140060376446784] Updating the best model with validation-mAP=0.9711081911611339
# [07/15/2020 02:53:27 INFO 140060376446784] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/15/2020 02:53:27 INFO 140060376446784] #progress_metric: host=algo-1, completed 46 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 7, "sum": 7.0, "min": 7}}, "EndTime": 1594781607.234619, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 6}, "StartTime": 1594781541.613858}
#
# [07/15/2020 02:53:59 INFO 140060376446784] Epoch:    7, batches:    100, num_examples:   1600, 50.2 samples/sec, epoch time so far:  0:00:31.873667
# [07/15/2020 02:54:20 WARNING 140060376446784] Expected number of batches: 171, did not match the number of batches processed: 172. This may happen when some images or annotations are invalid and cannot be parsed. Please check the dataset and ensure it follows the format in the documentation.
# [07/15/2020 02:54:20 INFO 140060376446784] #quality_metric: host=algo-1, epoch=7, batch=172 train cross_entropy <loss>=(0.5152255241803796)
# [07/15/2020 02:54:20 INFO 140060376446784] #quality_metric: host=algo-1, epoch=7, batch=172 train smooth_l1 <loss>=(0.2658481989604343)
# [07/15/2020 02:54:20 INFO 140060376446784] Round of batches complete
# [07/15/2020 02:54:21 INFO 140060376446784] Updated the metrics
# [07/15/2020 02:54:32 INFO 140060376446784] #quality_metric: host=algo-1, epoch=7, validation mAP <score>=(0.9768775565417869)
# [07/15/2020 02:54:32 INFO 140060376446784] Updating the best model with validation-mAP=0.9768775565417869
# [07/15/2020 02:54:32 INFO 140060376446784] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/15/2020 02:54:32 INFO 140060376446784] #progress_metric: host=algo-1, completed 53 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 8, "sum": 8.0, "min": 8}}, "EndTime": 1594781672.708413, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 7}, "StartTime": 1594781607.234844}
#
# [07/15/2020 02:55:05 INFO 140060376446784] Epoch:    8, batches:    100, num_examples:   1600, 49.5 samples/sec, epoch time so far:  0:00:32.337955
# [07/15/2020 02:55:26 WARNING 140060376446784] Expected number of batches: 171, did not match the number of batches processed: 172. This may happen when some images or annotations are invalid and cannot be parsed. Please check the dataset and ensure it follows the format in the documentation.
# [07/15/2020 02:55:26 INFO 140060376446784] #quality_metric: host=algo-1, epoch=8, batch=172 train cross_entropy <loss>=(0.49684688633684004)
# [07/15/2020 02:55:26 INFO 140060376446784] #quality_metric: host=algo-1, epoch=8, batch=172 train smooth_l1 <loss>=(0.24903643270297018)
# [07/15/2020 02:55:26 INFO 140060376446784] Round of batches complete
# [07/15/2020 02:55:26 INFO 140060376446784] Updated the metrics
# [07/15/2020 02:55:38 INFO 140060376446784] #quality_metric: host=algo-1, epoch=8, validation mAP <score>=(0.9751863808287875)
# [07/15/2020 02:55:38 INFO 140060376446784] #progress_metric: host=algo-1, completed 60 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 9, "sum": 9.0, "min": 9}}, "EndTime": 1594781738.762853, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 8}, "StartTime": 1594781672.708645}
#
# [07/15/2020 02:56:10 INFO 140060376446784] Epoch:    9, batches:    100, num_examples:   1600, 49.8 samples/sec, epoch time so far:  0:00:32.127775
# [07/15/2020 02:56:32 INFO 140060376446784] #quality_metric: host=algo-1, epoch=9, batch=171 train cross_entropy <loss>=(0.4771630415857459)
# [07/15/2020 02:56:32 INFO 140060376446784] #quality_metric: host=algo-1, epoch=9, batch=171 train smooth_l1 <loss>=(0.2323944911399747)
# [07/15/2020 02:56:32 INFO 140060376446784] Round of batches complete
# [07/15/2020 02:56:32 INFO 140060376446784] Updated the metrics
# [07/15/2020 02:56:44 INFO 140060376446784] #quality_metric: host=algo-1, epoch=9, validation mAP <score>=(0.9829917084789846)
# [07/15/2020 02:56:44 INFO 140060376446784] Updating the best model with validation-mAP=0.9829917084789846
# [07/15/2020 02:56:44 INFO 140060376446784] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/15/2020 02:56:44 INFO 140060376446784] #progress_metric: host=algo-1, completed 66 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1594781804.207349, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 9}, "StartTime": 1594781738.763087}
#
# [07/15/2020 02:57:16 INFO 140060376446784] Epoch:    10, batches:    100, num_examples:   1600, 49.5 samples/sec, epoch time so far:  0:00:32.316098
# [07/15/2020 02:57:37 WARNING 140060376446784] Expected number of batches: 171, did not match the number of batches processed: 172. This may happen when some images or annotations are invalid and cannot be parsed. Please check the dataset and ensure it follows the format in the documentation.
# [07/15/2020 02:57:37 INFO 140060376446784] #quality_metric: host=algo-1, epoch=10, batch=172 train cross_entropy <loss>=(0.4669261547919152)
# [07/15/2020 02:57:37 INFO 140060376446784] #quality_metric: host=algo-1, epoch=10, batch=172 train smooth_l1 <loss>=(0.21374946743640474)
# [07/15/2020 02:57:37 INFO 140060376446784] Round of batches complete
# [07/15/2020 02:57:38 INFO 140060376446784] Updated the metrics
# [07/15/2020 02:57:49 INFO 140060376446784] #quality_metric: host=algo-1, epoch=10, validation mAP <score>=(0.9859163699086753)
# [07/15/2020 02:57:49 INFO 140060376446784] Updating the best model with validation-mAP=0.9859163699086753
# [07/15/2020 02:57:49 INFO 140060376446784] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/15/2020 02:57:49 INFO 140060376446784] #progress_metric: host=algo-1, completed 73 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 11, "sum": 11.0, "min": 11}}, "EndTime": 1594781869.885205, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 10}, "StartTime": 1594781804.207638}
#
# [07/15/2020 02:58:21 INFO 140060376446784] Epoch:    11, batches:    100, num_examples:   1600, 50.0 samples/sec, epoch time so far:  0:00:31.978992
# [07/15/2020 02:58:43 WARNING 140060376446784] Expected number of batches: 171, did not match the number of batches processed: 172. This may happen when some images or annotations are invalid and cannot be parsed. Please check the dataset and ensure it follows the format in the documentation.
# [07/15/2020 02:58:43 INFO 140060376446784] #quality_metric: host=algo-1, epoch=11, batch=172 train cross_entropy <loss>=(0.4533735953130336)
# [07/15/2020 02:58:43 INFO 140060376446784] #quality_metric: host=algo-1, epoch=11, batch=172 train smooth_l1 <loss>=(0.20290058268681663)
# [07/15/2020 02:58:43 INFO 140060376446784] Round of batches complete
# [07/15/2020 02:58:43 INFO 140060376446784] Updated the metrics
# [07/15/2020 02:58:55 INFO 140060376446784] #quality_metric: host=algo-1, epoch=11, validation mAP <score>=(0.9871671342992026)
# [07/15/2020 02:58:55 INFO 140060376446784] Updating the best model with validation-mAP=0.9871671342992026
# [07/15/2020 02:58:56 INFO 140060376446784] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/15/2020 02:58:56 INFO 140060376446784] #progress_metric: host=algo-1, completed 80 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 12, "sum": 12.0, "min": 12}}, "EndTime": 1594781936.004445, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 11}, "StartTime": 1594781869.885474}
#
# [07/15/2020 02:59:28 INFO 140060376446784] Epoch:    12, batches:    100, num_examples:   1600, 49.5 samples/sec, epoch time so far:  0:00:32.302689
# [07/15/2020 02:59:49 INFO 140060376446784] #quality_metric: host=algo-1, epoch=12, batch=171 train cross_entropy <loss>=(0.43418965605816906)
# [07/15/2020 02:59:49 INFO 140060376446784] #quality_metric: host=algo-1, epoch=12, batch=171 train smooth_l1 <loss>=(0.1922098580331408)
# [07/15/2020 02:59:49 INFO 140060376446784] Round of batches complete
# [07/15/2020 02:59:49 INFO 140060376446784] Updated the metrics
# [07/15/2020 03:00:01 INFO 140060376446784] #quality_metric: host=algo-1, epoch=12, validation mAP <score>=(0.9922161655321176)
# [07/15/2020 03:00:01 INFO 140060376446784] Updating the best model with validation-mAP=0.9922161655321176
# [07/15/2020 03:00:01 INFO 140060376446784] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/15/2020 03:00:01 INFO 140060376446784] #progress_metric: host=algo-1, completed 86 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 13, "sum": 13.0, "min": 13}}, "EndTime": 1594782001.209095, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 12}, "StartTime": 1594781936.004692}
#
# [07/15/2020 03:00:33 INFO 140060376446784] Epoch:    13, batches:    100, num_examples:   1600, 49.9 samples/sec, epoch time so far:  0:00:32.071323
# [07/15/2020 03:00:54 WARNING 140060376446784] Expected number of batches: 171, did not match the number of batches processed: 172. This may happen when some images or annotations are invalid and cannot be parsed. Please check the dataset and ensure it follows the format in the documentation.
# [07/15/2020 03:00:54 INFO 140060376446784] #quality_metric: host=algo-1, epoch=13, batch=172 train cross_entropy <loss>=(0.42523070541970454)
# [07/15/2020 03:00:54 INFO 140060376446784] #quality_metric: host=algo-1, epoch=13, batch=172 train smooth_l1 <loss>=(0.17950499676199222)
# [07/15/2020 03:00:54 INFO 140060376446784] Round of batches complete
# [07/15/2020 03:00:54 INFO 140060376446784] Updated the metrics
# [07/15/2020 03:01:06 INFO 140060376446784] #quality_metric: host=algo-1, epoch=13, validation mAP <score>=(0.9926592584781411)
# [07/15/2020 03:01:06 INFO 140060376446784] Updating the best model with validation-mAP=0.9926592584781411
# [07/15/2020 03:01:06 INFO 140060376446784] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/15/2020 03:01:06 INFO 140060376446784] #progress_metric: host=algo-1, completed 93 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 14, "sum": 14.0, "min": 14}}, "EndTime": 1594782066.579225, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 13}, "StartTime": 1594782001.209336}
#
# [07/15/2020 03:01:38 INFO 140060376446784] Epoch:    14, batches:    100, num_examples:   1600, 49.7 samples/sec, epoch time so far:  0:00:32.202503
# [07/15/2020 03:02:00 WARNING 140060376446784] Expected number of batches: 171, did not match the number of batches processed: 172. This may happen when some images or annotations are invalid and cannot be parsed. Please check the dataset and ensure it follows the format in the documentation.
# [07/15/2020 03:02:00 INFO 140060376446784] #quality_metric: host=algo-1, epoch=14, batch=172 train cross_entropy <loss>=(0.4209609381012082)
# [07/15/2020 03:02:00 INFO 140060376446784] #quality_metric: host=algo-1, epoch=14, batch=172 train smooth_l1 <loss>=(0.1787968617847708)
# [07/15/2020 03:02:00 INFO 140060376446784] Round of batches complete
# [07/15/2020 03:02:00 INFO 140060376446784] Updated the metrics
# [07/15/2020 03:02:11 INFO 140060376446784] #quality_metric: host=algo-1, epoch=14, validation mAP <score>=(0.9922290122633464)
# [07/15/2020 03:02:11 INFO 140060376446784] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1594782131.762049, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 14}, "StartTime": 1594782066.579434}
#
# [07/15/2020 03:02:11 WARNING 140060376446784] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [07/15/2020 03:02:11 INFO 140060376446784] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/15/2020 03:02:11 INFO 140060376446784] Test data is not provided.
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}, "totaltime": {"count": 1, "max": 1017878.436088562, "sum": 1017878.436088562, "min": 1017878.436088562}, "setuptime": {"count": 1, "max": 11.651039123535156, "sum": 11.651039123535156, "min": 11.651039123535156}}, "EndTime": 1594782132.243435, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/Object Detection"}, "StartTime": 1594781114.496833}
#
#
# 2020-07-15 03:02:34 Uploading - Uploading generated training model
# 2020-07-15 03:02:34 Completed - Training job completed

# %% [markdown]
# # Deploy Model

# %%
deployed_model=model.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
print('\nModel Deployed!')
# Out:
# WARNING:sagemaker:Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# WARNING:sagemaker:Using already existing model: object-detection-2020-07-15-02-41-28-259
# ---------------!
# Model Deployed!

# %% [markdown]
# # Predictions

# %%
image_dir = 'validation'
images = [x for x in os.listdir(image_dir) if x[-3:] == 'jpg']
print(len(images))
# Out:
# 939

# %%
deployed_model.content_type='image/jpeg'

# %%
index = 0

image_path = os.path.join(image_dir, images[index])
#image_path = 'dog_cat.jfif'

with open(image_path, 'rb') as f:
    b = bytearray(f.read())

results = deployed_model.predict(b)
results = json.loads(results)

preds = results['prediction']

#print(results)

# %%
preds[0]
# Out:
# [0.0,
#  0.990879237651825,
#  0.41942188143730164,
#  0.24728737771511078,
#  0.8685926198959351,
#  0.5780165195465088]

# %%
img = Image.open(image_path)
draw = ImageDraw.Draw(img)
font = ImageFont.truetype('/usr/share/fonts/dejavu/DejaVuSerif-Bold.ttf', 30)
w, h =img.size

for pred in preds:
    class_id, score, xmin, ymin, xmax, ymax = pred
    
    if score > 0.7:
        box = [w*xmin, h*ymin, w*xmax, h*ymax]

        draw.rectangle(box, outline='yellow', width=4)
        draw.text((box[0], box[1]), classes[int(class_id)], font=font, fill='#000000')
    else:
        break

plt.xticks([])
plt.yticks([])
plt.imshow(img)
plt.show()

# %% [markdown]
# Don't forget!! You need to delete endpoint or else you will continue to accrue cost!

# %%
sagemaker.Session().delete_endpoint(deployed_model.endpoint)
